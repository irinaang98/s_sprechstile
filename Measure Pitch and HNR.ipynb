# %%
#Measure pitch of all wav files in directory
import glob
import numpy as np
import pandas as pd
import parselmouth
from parselmouth.praat import call

# %%
# This is the function to measure voice pitch
def measurePitch(voiceID, f0min, f0max, unit):
    sound = parselmouth.Sound(voiceID) # read the sound
    pitch = call(sound, "To Pitch", 0.0, f0min, f0max) #create a praat pitch object
    meanF0 = call(pitch, "Get mean", 0, 0, unit) # get mean pitch
    stdevF0 = call(pitch, "Get standard deviation", 0 ,0, unit) # get standard deviation
    harmonicity = call(sound, "To Harmonicity (cc)", 0.01, 75, 0.1, 1.0)
    hnr = call(harmonicity, "Get mean", 0, 0)
    return meanF0, stdevF0, hnr

# %%
# create lists to put the results
file_list = []
mean_F0_list = []
sd_F0_list = []
hnr_list = []

# Go through all the wave files in the folder and measure pitch
for wave_file in glob.glob(r"C:\Users\user\Desktop\MA Sprache und Kommunikation\2_Semester\Sprechstile\Angehelescu\Angehelescu*.wav"):
    #print (f'processing {os.path.basename(wave_file)}')
    sound = parselmouth.Sound(wave_file)
    (meanF0, stdevF0, hnr) = measurePitch(sound, 75, 500, "Hertz")
    file_list.append(wave_file) # make an ID list
    mean_F0_list.append(meanF0) # make a mean F0 list
    sd_F0_list.append(stdevF0) # make a sd F0 list
    hnr_list.append(hnr)

df = pd.DataFrame(np.column_stack([file_list, mean_F0_list, sd_F0_list, hnr_list]), 
                               columns=['voiceID', 'meanF0Hz', 'stdevF0Hz', 'HNR'])  #add these lists to pandas in the right order



# Write out the updated dataframe
df.to_csv("processed_results.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9029bbeab584> in <module>
#       7 # Go through all the wave files in the folder and measure pitch
#       8 for wave_file in glob.glob(r"C:\Users\user\Desktop\MA Sprache und Kommunikation\2_Semester\Sprechstile\Angehelescu\Angehelescu*.wav"):
# ----> 9     print (f'processing {os.path.basename(wave_file)}')
#      10     sound = parselmouth.Sound(wave_file)
#      11     (meanF0, stdevF0, hnr) = measurePitch(sound, 75, 500, "Hertz")
#
# NameError: name 'os' is not defined

# %%
df
# Out:
#                                               voiceID            meanF0Hz  \
# 0   C:\Users\user\Desktop\MA Sprache und Kommunika...   257.5500934222959
# 1   C:\Users\user\Desktop\MA Sprache und Kommunika...  255.23146682279332
# 2   C:\Users\user\Desktop\MA Sprache und Kommunika...  227.51245777976092
# 3   C:\Users\user\Desktop\MA Sprache und Kommunika...   250.0043037901158
# 4   C:\Users\user\Desktop\MA Sprache und Kommunika...   232.0011873353515
# 5   C:\Users\user\Desktop\MA Sprache und Kommunika...   250.4288879032285
# 6   C:\Users\user\Desktop\MA Sprache und Kommunika...  252.29848603584227
# 7   C:\Users\user\Desktop\MA Sprache und Kommunika...   268.5230016370887
# 8   C:\Users\user\Desktop\MA Sprache und Kommunika...   258.1267938872558
# 9   C:\Users\user\Desktop\MA Sprache und Kommunika...  242.01237479044832
# 10  C:\Users\user\Desktop\MA Sprache und Kommunika...  248.66603084529993
# 11  C:\Users\user\Desktop\MA Sprache und Kommunika...  255.24392496032874
# 12  C:\Users\user\Desktop\MA Sprache und Kommunika...  239.59080276980052
# 13  C:\Users\user\Desktop\MA Sprache und Kommunika...  238.90950331218784
# 14  C:\Users\user\Desktop\MA Sprache und Kommunika...  243.48743908451394
# 15  C:\Users\user\Desktop\MA Sprache und Kommunika...   250.4575828161032
# 16  C:\Users\user\Desktop\MA Sprache und Kommunika...  243.20309084669262
# 17  C:\Users\user\Desktop\MA Sprache und Kommunika...  239.89662428834706
# 18  C:\Users\user\Desktop\MA Sprache und Kommunika...  250.69700370387218
# 19  C:\Users\user\Desktop\MA Sprache und Kommunika...   239.3254846098407
# 20  C:\Users\user\Desktop\MA Sprache und Kommunika...   261.0116512471278
# 21  C:\Users\user\Desktop\MA Sprache und Kommunika...  211.63139710233494
